# %% [markdown]
# https://www.kaggle.com/c/womens-machine-learning-competition-2018

# %% [markdown]
# # Info

# %% [markdown]
# **What to predict:**
#
# * Stage 1 - You should submit predicted probabilities for every possible matchup in the past 4 NCAA® tournaments (2014-2017).
# * Stage 2 - You should submit predicted probabilities for every possible matchup before the 2018 tournament begins.

# %% [markdown]
# * During any given season, day number zero is defined to be exactly 19 weeks earlier than Selection Monday, so Day #0 is a Monday in late October or early November such that Day #132 is Selection Sunday (for the men's tournament) and Day #133 is Selection Monday (for the women's tournament).
#
# * This doesn't necessarily mean that the regular season will always start exactly on Day #0; in fact, during the past decade, regular season games typically start being played on a Friday that is either Day #4 or Day #11, but further back there was more variety.
#
# * There are no teams that ever played more than one game on a given date, so you can use this fact if you need a unique key (combining Season and DayNum and WTeamID).

# %% [markdown]
# 2017 season and 2018 season:
#
#     Round 1 = days 137/138 (Fri/Sat)
#     Round 2 = days 139/140 (Sun/Mon)
#     Round 3 = days 144/145 (Sweet Sixteen, Fri/Sat)
#     Round 4 = days 146/147 (Elite Eight, Sun/Mon)
#     National Seminfinal = day 151 (Fri)
#     National Final = day 153 (Sun)
#
# 2015 season and 2016 season:
#
#     Round 1 = days 137/138 (Fri/Sat)
#     Round 2 = days 139/140 (Sun/Mon)
#     Round 3 = days 144/145 (Sweet Sixteen, Fri/Sat)
#     Round 4 = days 146/147 (Elite Eight, Sun/Mon)
#     National Seminfinal = day 153 (Sun)
#     National Final = day 155 (Tue)
#
# 2003 season through 2014 season:
#
#     Round 1 = days 138/139 (Sat/Sun)
#     Round 2 = days 140/141 (Mon/Tue)
#     Round 3 = days 145/146 (Sweet Sixteen, Sat/Sun)
#     Round 4 = days 147/148 (Elite Eight, Mon/Tue)
#     National Seminfinal = day 153 (Sun)
#     National Final = day 155 (Tue)
#
# 1998 season through 2002 season:
#
#     Round 1 = days 137/138 (Fri/Sat)
#     Round 2 = days 139/140 (Sun/Mon)
#     Round 3 = day 145 only (Sweet Sixteen, Sat)
#     Round 4 = day 147 only (Elite Eight, Mon)
#     National Seminfinal = day 151 (Fri)
#     National Final = day 153 (Sun)

# %% [markdown]
# # Import / Utils

# %%
import os, math, re, datetime, sklearn, warnings
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from pathlib import Path
from sklearn_pandas import DataFrameMapper
from sklearn.preprocessing import StandardScaler
from pandas.api.types import is_string_dtype, is_numeric_dtype
from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import forest
from sklearn.metrics import r2_score
from multiprocessing import cpu_count
# %matplotlib inline

pd.set_option('display.max_columns', None)

# %%
def set_rf_samples(n):
    """ Changes Scikit learn's random forests to give each tree a random sample of
    n random rows.
    """
    forest._generate_sample_indices = (lambda rs, n_samples:
        forest.check_random_state(rs).randint(0, n_samples, n))

def reset_rf_samples():
    """ Undoes the changes produced by set_rf_samples.
    """
    forest._generate_sample_indices = (lambda rs, n_samples:
        forest.check_random_state(rs).randint(0, n_samples, n_samples))

def df_splits(df, val=0.15, test=None):
    if test is None: test = 0.0
    n = len(df)
    idxs = np.random.permutation(n)
    n_val, n_test = int(n*val), int(n*test)
    val_idxs = idxs[:n_val]
    test_idxs = idxs[n_val:n_val+n_test]
    train_idxs = idxs[n_val+n_test:]
    
    return df.iloc[train_idxs], df.iloc[val_idxs], df.iloc[test_idxs]

def add_datepart(df, fldname, drop=True):
    fld = df[fldname]
    if not np.issubdtype(fld.dtype, np.datetime64):
        df[fldname] = fld = pd.to_datetime(fld, infer_datetime_format=True)
    targ_pre = re.sub('[Dd]ate$', '', fldname)
    for n in ('Year', 'Month', 'Week', 'Day', 'Dayofweek', 'Dayofyear',
            'Is_month_end', 'Is_month_start', 'Is_quarter_end', 'Is_quarter_start', 'Is_year_end', 'Is_year_start'):
        df[targ_pre+n] = getattr(fld.dt,n.lower())
    df[targ_pre+'Elapsed'] = fld.astype(np.int64) // 10**9
    if drop: df.drop(fldname, axis=1, inplace=True)

def get_sample(df,n):
    """ Gets a random sample of n rows from df, without replacement."""
    idxs = sorted(np.random.permutation(len(df))[:n])
    return df.iloc[idxs].copy()

def train_cats(df):
    '''Change any columns of strings in a panda's dataframe to a column of
    catagorical values. This applies the changes inplace.'''
    for n,c in df.items():
        if is_string_dtype(c): df[n] = c.astype('category').cat.as_ordered()

def apply_cats(df, trn):
    '''Changes any columns of strings in df into categorical variables using trn as
    a template for the category codes.'''
    for n,c in df.items():
        if (n in trn.columns) and (trn[n].dtype.name=='category'):
            df[n] = pd.Categorical(c, categories=trn[n].cat.categories, ordered=True)

def fix_missing(df, col, name, na_dict):
    '''Fill missing data in a column of df with the median, and add a {name}_na column
    which specifies if the data was missing.'''
    if is_numeric_dtype(col):
        if pd.isnull(col).sum() or (name in na_dict):
            df[name+'_na'] = pd.isnull(col)
            filler = na_dict[name] if name in na_dict else col.median()
            df[name] = col.fillna(filler)
            na_dict[name] = filler
    return na_dict

def numericalize(df, col, name, max_n_cat):
    ''' Changes the column col from a categorical type to it's integer codes.

    Parameters:
    -----------
    df: A pandas dataframe. df[name] will be filled with the integer codes from
        col.

    col: The column you wish to change into the categories.
    name: The column name you wish to insert into df. This column will hold the
        integer codes.

    max_n_cat: If col has more categories than max_n_cat it will not change the
        it to its integer codes. If max_n_cat is None, then col will always be
        converted.'''
    if not is_numeric_dtype(col) and ( max_n_cat is None or col.nunique()>max_n_cat):
        df[name] = col.cat.codes+1

def scale_vars(df, mapper):
    warnings.filterwarnings('ignore', category=sklearn.exceptions.DataConversionWarning)
    if mapper is None:
        map_f = [([n],StandardScaler()) for n in df.columns if is_numeric_dtype(df[n])]
        mapper = DataFrameMapper(map_f).fit(df)
    df[mapper.transformed_names_] = mapper.transform(df)
    return mapper

def proc_df(df, y_fld, skip_flds=None, do_scale=False, na_dict=None,
            preproc_fn=None, max_n_cat=None, subset=None, mapper=None):

    """ proc_df takes a data frame df and splits off the response variable, and
    changes the df into an entirely numeric dataframe.

    Parameters:
    -----------
    df: The data frame you wish to process.

    y_fld: The name of the response variable

    skip_flds: A list of fields that dropped from df.

    do_scale: Standardizes each column in df,Takes Boolean Values(True,False)

    na_dict: a dictionary of na columns to add. Na columns are also added if there
        are any missing values.

    preproc_fn: A function that gets applied to df.

    max_n_cat: The maximum number of categories to break into dummy values, instead
        of integer codes.

    subset: Takes a random subset of size subset from df.

    mapper: If do_scale is set as True, the mapper variable
        calculates the values used for scaling of variables during training time(mean and standard deviation).

    Returns:
    --------
    [x, y, nas, mapper(optional)]:

        x: x is the transformed version of df. x will not have the response variable
            and is entirely numeric.

        y: y is the response variable

        nas: returns a dictionary of which nas it created, and the associated median.

        mapper: A DataFrameMapper which stores the mean and standard deviation of the corresponding continous
        variables which is then used for scaling of during test-time.

    Examples:
    ---------
    >>> df = pd.DataFrame({'col1' : [1, 2, 3], 'col2' : ['a', 'b', 'a']})
    >>> df
       col1 col2
    0     1    a
    1     2    b
    2     3    a

    note the type of col2 is string

    >>> train_cats(df)
    >>> df

       col1 col2
    0     1    a
    1     2    b
    2     3    a

    now the type of col2 is category { a : 1, b : 2}

    >>> x, y, nas = proc_df(df, 'col1')
    >>> x

       col2
    0     1
    1     2
    2     1

    >>> data = DataFrame(pet=["cat", "dog", "dog", "fish", "cat", "dog", "cat", "fish"],
                 children=[4., 6, 3, 3, 2, 3, 5, 4],
                 salary=[90, 24, 44, 27, 32, 59, 36, 27])

    >>> mapper = DataFrameMapper([(:pet, LabelBinarizer()),
                          ([:children], StandardScaler())])

    >>>round(fit_transform!(mapper, copy(data)), 2)

    8x4 Array{Float64,2}:
    1.0  0.0  0.0   0.21
    0.0  1.0  0.0   1.88
    0.0  1.0  0.0  -0.63
    0.0  0.0  1.0  -0.63
    1.0  0.0  0.0  -1.46
    0.0  1.0  0.0  -0.63
    1.0  0.0  0.0   1.04
    0.0  0.0  1.0   0.21
    """
    if not skip_flds: skip_flds=[]
    if subset: df = get_sample(df,subset)
    df = df.copy()
    if preproc_fn: preproc_fn(df)
    y = df[y_fld].values
    df.drop(skip_flds+[y_fld], axis=1, inplace=True)

    if na_dict is None: na_dict = {}
    for n,c in df.items(): na_dict = fix_missing(df, c, n, na_dict)
    if do_scale: mapper = scale_vars(df, mapper)
    for n,c in df.items(): numericalize(df, c, n, max_n_cat)
    res = [pd.get_dummies(df, dummy_na=True), y, na_dict]
    if do_scale: res = res + [mapper]
    return res

# %% [markdown]
# # Read files / preprocess

# %% [markdown]
# ## notes

# %% [markdown]
# **WLoc:**
# * "H" winning team court
# * "A" lossing team court
# * "N" neutral court
#
# **NumOT:** this indicates the number of overtime periods in the game, an integer 0 or higher.
#
#
# **Used Files:**
# * (x) WCities.csv
# * ( ) WGameCities.csv
# * (x) WNCAATourneyCompactResults.csv
# * (x) WNCAATourneySeeds.csv
# * (x) WNCAATourneySlots.csv
# * (x) WRegularSeasonCompactResults.csv
# * (x) WSampleSubmissionStage1.csv
# * (x) WSeasons.csv
# * ( ) WTeams.csv
# * ( ) WTeamSpellings.csv

# %% [markdown]
# * (x) WCities.csv
# * ( ) WGameCities.csv
# * (x) WNCAATourneyCompactResults.csv
# * (x) WNCAATourneySeeds.csv
# * (x) WNCAATourneySlots.csv
# * (x) WRegularSeasonCompactResults.csv
# * (x) WSampleSubmissionStage1.csv
# * (x) WSeasons.csv
# * ( ) WTeams.csv
# * ( ) WTeamSpellings.csv

# %% [markdown]
# ## Read data

# %%
path = Path(os.environ['HOME']+'/datasets/kaggle/basket-woman/')

# %%
def add_seed_data(df):
    tcols = ['region_code', 'region_seed', 'region_name']
    # Team 1
    df = df.merge(df_tourney_seeds.drop('Seed', axis=1), 'left',
                  left_on=['Season', 'T1'], right_on=['Season', 'TeamID'])
    df.drop('TeamID', axis=1, inplace=True)
    df.rename(columns={c:f'T1_{c}' for c in tcols}, inplace=True)
    # Team 2
    df = df.merge(df_tourney_seeds.drop('Seed', axis=1), 'left',
                  left_on=['Season', 'T2'], right_on=['Season', 'TeamID'])
    df.drop('TeamID', axis=1, inplace=True)
    df.rename(columns={c:f'T2_{c}' for c in tcols}, inplace=True)
    return df

def add_results_data(df):
    n = df.columns.shape[0]
    for dff in [df_wins, df_losses, df_win_scores, df_loss_scores]:
        df = df.merge(dff, 'left', left_on='T1', right_index=True)
    df.columns = [c if i < n else f'T1_{c}' for i,c in enumerate(df.columns)]
    
    n = df.columns.shape[0]
    for dff in [df_wins, df_losses, df_win_scores, df_loss_scores]:
        df = df.merge(dff, 'left', left_on='T2', right_index=True)
    df.columns = [c if i < n else f'T2_{c}' for i,c in enumerate(df.columns)]
    
    return df

# %%
# Seasons
df_seasons = pd.read_csv(path / 'WSeasons.csv', parse_dates=['DayZero'], low_memory=False)
df_seasons.set_index('Season', inplace=True)

# Seeds
df_tourney_seeds = pd.read_csv(path / 'WNCAATourneySeeds.csv', low_memory=False)
df_tourney_seeds['region_code'] = df_tourney_seeds['Seed'].str.slice(0,1)
df_tourney_seeds['region_seed'] = df_tourney_seeds['Seed'].str.slice(1).astype(int)
df_tourney_seeds['region_name'] = df_tourney_seeds.apply(lambda x:
    df_seasons.at[x['Season'], f'Region{x.region_code}'], axis=1)

# Results
df_season_results = pd.read_csv(path / 'WRegularSeasonCompactResults.csv', low_memory=False)
df_season_results['NCAA'] = False
df_tourney_results = pd.read_csv(path / 'WNCAATourneyCompactResults.csv', low_memory=False)
df_tourney_results['NCAA'] = True
df_results = pd.concat([df_season_results, df_tourney_results])

# %%
df_wins = df_results.groupby(['Season', 'WTeamID'])[['DayNum']].count().unstack(-2)
df_wins.columns = [f'wins_{l}' for l in df_wins.columns.droplevel()]
df_wins.head(3)
# Out:
#          wins_1998  wins_1999  wins_2000  wins_2001  wins_2002  wins_2003  \
# WTeamID
# 3101           NaN        NaN        NaN        NaN        NaN        NaN
# 3102           4.0        4.0        3.0        3.0        3.0        6.0
# 3103          11.0       16.0       11.0        6.0        1.0        2.0
#
#          wins_2004  wins_2005  wins_2006  wins_2007  wins_2008  wins_2009  \
# WTeamID
# 3101           NaN        NaN        NaN        NaN        NaN        NaN
# 3102           1.0        6.0       11.0        6.0        8.0        2.0
# 3103           7.0        3.0        5.0       10.0        7.0       11.0
#
#          wins_2010  wins_2011  wins_2012  wins_2013  wins_2014  wins_2015  \
# WTeamID
# 3101           NaN        NaN        NaN        NaN       11.0       13.0
# 3102           1.0        8.0        6.0        4.0        1.0        2.0
# 3103          17.0       13.0       14.0       22.0       22.0       21.0
#
#          wins_2016  wins_2017
# WTeamID
# 3101          22.0       19.0
# 3102           1.0        4.0
# 3103          18.0        7.0

# %%
df_losses = df_results.groupby(['Season', 'LTeamID'])[['DayNum']].count().unstack(-2)
df_losses.columns = [f'losses_{l}' for l in df_losses.columns.droplevel()]
df_losses.head(3)
# Out:
#          losses_1998  losses_1999  losses_2000  losses_2001  losses_2002  \
# LTeamID
# 3101             NaN          NaN          NaN          NaN          NaN
# 3102            20.0         21.0         24.0         24.0         22.0
# 3103            18.0         12.0         18.0         23.0         27.0
#
#          losses_2003  losses_2004  losses_2005  losses_2006  losses_2007  \
# LTeamID
# 3101             NaN          NaN          NaN          NaN          NaN
# 3102            20.0         25.0         21.0         15.0         22.0
# 3103            26.0         21.0         25.0         23.0         19.0
#
#          losses_2008  losses_2009  losses_2010  losses_2011  losses_2012  \
# LTeamID
# 3101             NaN          NaN          NaN          NaN          NaN
# 3102            19.0         26.0         27.0         22.0         24.0
# 3103            24.0         19.0         13.0         16.0         18.0
#
#          losses_2013  losses_2014  losses_2015  losses_2016  losses_2017
# LTeamID
# 3101             NaN         12.0         12.0          3.0          8.0
# 3102            26.0         28.0         28.0         29.0         25.0
# 3103             9.0         10.0          8.0         13.0         21.0

# %%
df_win_scores = df_results.groupby(['Season', 'WTeamID'])[['WScore']].sum().unstack(-2)
df_win_scores.columns = [f'win_scores_{l}' for l in df_win_scores.columns.droplevel()]
df_win_scores.head(3)
# Out:
#          win_scores_1998  win_scores_1999  win_scores_2000  win_scores_2001  \
# WTeamID
# 3101                 NaN              NaN              NaN              NaN
# 3102               263.0            251.0            230.0            220.0
# 3103               842.0           1185.0            825.0            416.0
#
#          win_scores_2002  win_scores_2003  win_scores_2004  win_scores_2005  \
# WTeamID
# 3101                 NaN              NaN              NaN              NaN
# 3102               220.0            445.0             57.0            399.0
# 3103                72.0            132.0            432.0            194.0
#
#          win_scores_2006  win_scores_2007  win_scores_2008  win_scores_2009  \
# WTeamID
# 3101                 NaN              NaN              NaN              NaN
# 3102               806.0            386.0            517.0            133.0
# 3103               324.0            648.0            519.0            713.0
#
#          win_scores_2010  win_scores_2011  win_scores_2012  win_scores_2013  \
# WTeamID
# 3101                 NaN              NaN              NaN              NaN
# 3102                68.0            558.0            390.0            303.0
# 3103              1128.0            959.0           1159.0           1725.0
#
#          win_scores_2014  win_scores_2015  win_scores_2016  win_scores_2017
# WTeamID
# 3101               863.0            970.0           1666.0           1460.0
# 3102                82.0            148.0             59.0            246.0
# 3103              1903.0           1629.0           1312.0            534.0

# %%
df_loss_scores = df_results.groupby(['Season', 'LTeamID'])[['LScore']].sum().unstack(-2)
df_loss_scores.columns = [f'loss_scores_{l}' for l in df_loss_scores.columns.droplevel()]
df_loss_scores.head(3)
# Out:
#          loss_scores_1998  loss_scores_1999  loss_scores_2000  \
# LTeamID
# 3101                  NaN               NaN               NaN
# 3102               1112.0            1094.0            1350.0
# 3103               1166.0             792.0            1092.0
#
#          loss_scores_2001  loss_scores_2002  loss_scores_2003  \
# LTeamID
# 3101                  NaN               NaN               NaN
# 3102               1132.0            1219.0            1061.0
# 3103               1243.0            1479.0            1359.0
#
#          loss_scores_2004  loss_scores_2005  loss_scores_2006  \
# LTeamID
# 3101                  NaN               NaN               NaN
# 3102               1338.0            1162.0             803.0
# 3103               1138.0            1346.0            1204.0
#
#          loss_scores_2007  loss_scores_2008  loss_scores_2009  \
# LTeamID
# 3101                  NaN               NaN               NaN
# 3102               1109.0             965.0            1189.0
# 3103               1094.0            1408.0            1073.0
#
#          loss_scores_2010  loss_scores_2011  loss_scores_2012  \
# LTeamID
# 3101                  NaN               NaN               NaN
# 3102               1383.0            1257.0            1229.0
# 3103                739.0             927.0            1202.0
#
#          loss_scores_2013  loss_scores_2014  loss_scores_2015  \
# LTeamID
# 3101                  NaN             747.0             656.0
# 3102               1394.0            1473.0            1466.0
# 3103                614.0             717.0             513.0
#
#          loss_scores_2016  loss_scores_2017
# LTeamID
# 3101                164.0             454.0
# 3102               1363.0            1305.0
# 3103                868.0            1212.0

# %%
df_results.drop(['DayNum', 'WScore', 'LScore', 'WLoc', 'NumOT'], axis=1, inplace=True)
df_data_1 = df_results.copy()
df_data_1.columns = ['Season', 'T1', 'T2', 'NCAA']
df_data_1['Pred'] = 1.0
df_data_2 = df_results.copy()
df_data_2.columns = ['Season', 'T2', 'T1', 'NCAA']
df_data_2['Pred'] = 0.0
df_data = pd.concat([df_data_1, df_data_2])
df_data = add_seed_data(df_data)
df_data = add_results_data(df_data)
df_data['seed_diff'] = df_data.T1_region_seed - df_data.T2_region_seed

# %%
train_cats(df_data)
df_data.shape
# Out:
# (195890, 172)

# %%
df_data.head(3)
# Out:
#     NCAA  Pred  Season    T1    T2 T1_region_code  T1_region_seed  \
# 0  False   1.0    1998  3104  3202              X             2.0
# 1  False   1.0    1998  3163  3221              W             2.0
# 2  False   1.0    1998  3222  3261            NaN             NaN
#
#   T1_region_name T2_region_code  T2_region_seed T2_region_name  T1_wins_1998  \
# 0        Midwest            NaN             NaN            NaN          23.0
# 1           East              X            14.0        Midwest          33.0
# 2            NaN            NaN             NaN            NaN           9.0
#
#    T1_wins_1999  T1_wins_2000  T1_wins_2001  T1_wins_2002  T1_wins_2003  \
# 0          20.0          15.0          18.0          16.0          13.0
# 1          29.0          36.0          32.0          39.0          37.0
# 2           4.0           7.0          19.0          22.0          15.0
#
#    T1_wins_2004  T1_wins_2005  T1_wins_2006  T1_wins_2007  T1_wins_2008  \
# 0          12.0          14.0           9.0          10.0           8.0
# 1          31.0          25.0          32.0          32.0          36.0
# 2          28.0          21.0          12.0           8.0          15.0
#
#    T1_wins_2009  T1_wins_2010  T1_wins_2011  T1_wins_2012  T1_wins_2013  \
# 0          13.0          12.0          16.0          12.0          13.0
# 1          39.0          39.0          36.0          33.0          35.0
# 2          19.0          17.0          26.0           3.0          13.0
#
#    T1_wins_2014  T1_wins_2015  T1_wins_2016  T1_wins_2017  T1_losses_1998  \
# 0          14.0          13.0          15.0          19.0            10.0
# 1          40.0          38.0          38.0          36.0             3.0
# 2           6.0           6.0           6.0          12.0            17.0
#
#    T1_losses_1999  T1_losses_2000  T1_losses_2001  T1_losses_2002  \
# 0            11.0            13.0            11.0            11.0
# 1             5.0             1.0             3.0             NaN
# 2            22.0            22.0            12.0             7.0
#
#    T1_losses_2003  T1_losses_2004  T1_losses_2005  T1_losses_2006  \
# 0            15.0            16.0            14.0            19.0
# 1             1.0             4.0             8.0             5.0
# 2            13.0             4.0             9.0            17.0
#
#    T1_losses_2007  T1_losses_2008  T1_losses_2009  T1_losses_2010  \
# 0            20.0            22.0            17.0            18.0
# 1             4.0             2.0             NaN             NaN
# 2            19.0            16.0            10.0            14.0
#
#    T1_losses_2011  T1_losses_2012  T1_losses_2013  T1_losses_2014  \
# 0            14.0            19.0            18.0            16.0
# 1             2.0             5.0             4.0             NaN
# 2             6.0            26.0            17.0            25.0
#
#    T1_losses_2015  T1_losses_2016  T1_losses_2017  T1_win_scores_1998  \
# 0            19.0            15.0            13.0              1826.0
# 1             1.0             NaN             1.0              2799.0
# 2            24.0            24.0            19.0               646.0
#
#    T1_win_scores_1999  T1_win_scores_2000  T1_win_scores_2001  \
# 0              1652.0              1131.0              1207.0
# 1              2742.0              3113.0              2796.0
# 2               268.0               498.0              1505.0
#
#    T1_win_scores_2002  T1_win_scores_2003  T1_win_scores_2004  \
# 0              1240.0               930.0               907.0
# 1              3394.0              2793.0              2398.0
# 2              1608.0              1186.0              1930.0
#
#    T1_win_scores_2005  T1_win_scores_2006  T1_win_scores_2007  \
# 0              1018.0               634.0               735.0
# 1              1869.0              2399.0              2544.0
# 2              1495.0               836.0               659.0
#
#    T1_win_scores_2008  T1_win_scores_2009  T1_win_scores_2010  \
# 0               499.0               915.0               862.0
# 1              2942.0              3274.0              3162.0
# 2              1092.0              1342.0              1274.0
#
#    T1_win_scores_2011  T1_win_scores_2012  T1_win_scores_2013  \
# 0              1211.0               833.0               969.0
# 1              2787.0              2585.0              2930.0
# 2              2027.0               205.0               892.0
#
#    T1_win_scores_2014  T1_win_scores_2015  T1_win_scores_2016  \
# 0              1014.0               892.0              1102.0
# 1              3283.0              3395.0              3346.0
# 2               382.0               357.0               384.0
#
#    T1_win_scores_2017  T1_loss_scores_1998  T1_loss_scores_1999  \
# 0              1461.0                697.0                751.0
# 1              3158.0                191.0                358.0
# 2               857.0               1051.0               1435.0
#
#    T1_loss_scores_2000  T1_loss_scores_2001  T1_loss_scores_2002  \
# 0                767.0                634.0                726.0
# 1                 71.0                239.0                  NaN
# 2               1317.0                789.0                430.0
#
#    T1_loss_scores_2003  T1_loss_scores_2004  T1_loss_scores_2005  \
# 0                835.0                951.0                839.0
# 1                 48.0                244.0                461.0
# 2                835.0                242.0                490.0
#
#    T1_loss_scores_2006  T1_loss_scores_2007  T1_loss_scores_2008  \
# 0               1062.0               1071.0               1147.0
# 1                293.0                237.0                144.0
# 2                952.0               1044.0               1005.0
#
#    T1_loss_scores_2009  T1_loss_scores_2010  T1_loss_scores_2011  \
# 0                989.0               1059.0                757.0
# 1                  NaN                  NaN                122.0
# 2                612.0                893.0                357.0
#
#    T1_loss_scores_2012  T1_loss_scores_2013  T1_loss_scores_2014  \
# 0               1007.0               1044.0                930.0
# 1                318.0                288.0                  NaN
# 2               1330.0               1011.0               1287.0
#
#    T1_loss_scores_2015  T1_loss_scores_2016  T1_loss_scores_2017  \
# 0               1017.0                821.0                718.0
# 1                 86.0                  NaN                 64.0
# 2               1241.0               1286.0               1039.0
#
#    T2_wins_1998  T2_wins_1999  T2_wins_2000  T2_wins_2001  T2_wins_2002  \
# 0          15.0          13.0          20.0          18.0          17.0
# 1          21.0          21.0          23.0          21.0          22.0
# 2          17.0          22.0          25.0          20.0          18.0
#
#    T2_wins_2003  T2_wins_2004  T2_wins_2005  T2_wins_2006  T2_wins_2007  \
# 0          15.0          17.0          17.0           9.0           9.0
# 1          24.0          13.0          20.0          16.0          15.0
# 2          30.0          27.0          33.0          31.0          30.0
#
#    T2_wins_2008  T2_wins_2009  T2_wins_2010  T2_wins_2011  T2_wins_2012  \
# 0           9.0          11.0           7.0          13.0          15.0
# 1          19.0          13.0          10.0          10.0          18.0
# 2          31.0          19.0          21.0          19.0          23.0
#
#    T2_wins_2013  T2_wins_2014  T2_wins_2015  T2_wins_2016  T2_wins_2017  \
# 0          11.0          16.0          17.0          13.0          11.0
# 1          18.0          20.0          15.0          13.0           8.0
# 2          22.0          21.0          17.0          10.0          20.0
#
#    T2_losses_1998  T2_losses_1999  T2_losses_2000  T2_losses_2001  \
# 0            13.0            14.0            11.0            10.0
# 1             8.0             8.0             7.0             9.0
# 2            12.0             8.0             7.0            11.0
#
#    T2_losses_2002  T2_losses_2003  T2_losses_2004  T2_losses_2005  \
# 0            12.0            13.0            11.0            10.0
# 1             7.0             8.0            15.0            11.0
# 2            12.0             4.0             8.0             3.0
#
#    T2_losses_2006  T2_losses_2007  T2_losses_2008  T2_losses_2009  \
# 0            20.0            20.0            20.0            18.0
# 1            14.0            18.0            13.0            17.0
# 2             4.0             8.0             6.0            11.0
#
#    T2_losses_2010  T2_losses_2011  T2_losses_2012  T2_losses_2013  \
# 0            24.0            16.0            16.0            18.0
# 1            21.0            20.0            14.0            14.0
# 2            10.0            13.0            11.0            12.0
#
#    T2_losses_2014  T2_losses_2015  T2_losses_2016  T2_losses_2017  \
# 0            12.0            13.0            16.0            17.0
# 1            12.0            17.0            17.0            22.0
# 2            13.0            14.0            21.0            12.0
#
#    T2_win_scores_1998  T2_win_scores_1999  T2_win_scores_2000  \
# 0              1143.0               938.0              1560.0
# 1              1715.0              1639.0              1814.0
# 2              1262.0              1747.0              1814.0
#
#    T2_win_scores_2001  T2_win_scores_2002  T2_win_scores_2003  \
# 0              1356.0              1231.0              1130.0
# 1              1585.0              1723.0              1755.0
# 2              1516.0              1439.0              2336.0
#
#    T2_win_scores_2004  T2_win_scores_2005  T2_win_scores_2006  \
# 0              1186.0              1172.0               649.0
# 1               931.0              1410.0              1107.0
# 2              2093.0              2417.0              2362.0
#
#    T2_win_scores_2007  T2_win_scores_2008  T2_win_scores_2009  \
# 0               537.0               641.0               807.0
# 1              1013.0              1207.0               892.0
# 2              2060.0              2230.0              1186.0
#
#    T2_win_scores_2010  T2_win_scores_2011  T2_win_scores_2012  \
# 0               469.0               865.0              1000.0
# 1               623.0               706.0              1233.0
# 2              1502.0              1282.0              1456.0
#
#    T2_win_scores_2013  T2_win_scores_2014  T2_win_scores_2015  \
# 0               731.0              1160.0              1201.0
# 1              1174.0              1513.0               994.0
# 2              1605.0              1576.0              1188.0
#
#    T2_win_scores_2016  T2_win_scores_2017  T2_loss_scores_1998  \
# 0               950.0               708.0                859.0
# 1               859.0               478.0                538.0
# 2               647.0              1367.0                730.0
#
#    T2_loss_scores_1999  T2_loss_scores_2000  T2_loss_scores_2001  \
# 0                883.0                624.0                608.0
# 1                497.0                399.0                530.0
# 2                484.0                404.0                694.0
#
#    T2_loss_scores_2002  T2_loss_scores_2003  T2_loss_scores_2004  \
# 0                799.0                710.0                675.0
# 1                479.0                418.0                954.0
# 2                749.0                257.0                470.0
#
#    T2_loss_scores_2005  T2_loss_scores_2006  T2_loss_scores_2007  \
# 0                603.0               1115.0               1063.0
# 1                618.0                777.0                893.0
# 2                171.0                233.0                445.0
#
#    T2_loss_scores_2008  T2_loss_scores_2009  T2_loss_scores_2010  \
# 0               1102.0                978.0               1261.0
# 1                661.0                930.0               1218.0
# 2                331.0                608.0                622.0
#
#    T2_loss_scores_2011  T2_loss_scores_2012  T2_loss_scores_2013  \
# 0                914.0                893.0                991.0
# 1               1109.0                785.0                742.0
# 2                699.0                659.0                741.0
#
#    T2_loss_scores_2014  T2_loss_scores_2015  T2_loss_scores_2016  \
# 0                696.0                807.0                860.0
# 1                742.0                993.0                955.0
# 2                803.0                773.0               1041.0
#
#    T2_loss_scores_2017  seed_diff
# 0                969.0        NaN
# 1               1214.0      -12.0
# 2                663.0        NaN

# %%
df_data.to_feather('data/df_data')

# %%
df_data = pd.read_feather('data/df_data')

# %%
# !ls -lh data
# Out:
# total 265M
# -rw-r--r-- 1 rhermoza rhermoza 255M Feb 26 00:23 df_data
# -rw-r--r-- 1 rhermoza rhermoza  11M Feb 25 23:39 df_submission

# %% [markdown]
# ## Preprocess to model

# %%
np.random.seed(34)
df_train, df_val, _ = df_splits(df_data, 0.2)
df_train.shape, df_val.shape
# Out:
# ((156712, 172), (39178, 172))

# %%
x_train, y_train, nas = proc_df(df_train, 'Pred')
x_val, y_val, _ = proc_df(df_val, 'Pred', na_dict=nas)
# x_test, y_test, _ = proc_df(df_test, 'Pred', na_dict=nas)
# nas

# %% [markdown]
# # Random forest

# %% [markdown]
# Evaluation
#
# $$\textrm{LogLoss} = - \frac{1}{n} \sum_{i=1}^n \left[ y_i \log(\hat{y}_i) + (1 - y_i) \log(1 - \hat{y}_i)\right],$$
#
# where:
# * n: is the number of games played
# * y^i: is the predicted probability of team 1 beating team 2
# * yi: is 1 if team 1 wins, 0 if team 2 wins
# * log():  is the natural (base e) logarithm
#
# A smaller log loss is better. Games which are not played are ignored in the scoring. The use of the logarithm provides extreme punishments for being both confident and wrong. In the worst possible case, a prediction that something is true when it is actually false will add infinite to your error score. In order to prevent this, predictions are bounded away from the extremes by a small value.

# %%
x_train.head()
# Out:
#          NCAA  Season    T1    T2  T1_region_code  T1_region_seed  \
# 15903   False    2001  3281  3242               1            10.0
# 149393  False    2009  3441  3172               4            13.0
# 571     False    1998  3241  3291               0             8.0
# 36154   False    2006  3265  3165               3            14.0
# 156278  False    2010  3155  3448               0             8.0
#
#         T1_region_name  T2_region_code  T2_region_seed  T2_region_name  \
# 15903               10               0             8.0               0
# 149393              26               0             8.0               0
# 571                  0               0             8.0               0
# 36154                4               0             8.0               0
# 156278               0               0             8.0               0
#
#         T1_wins_1998  T1_wins_1999  T1_wins_2000  T1_wins_2001  T1_wins_2002  \
# 15903           10.0          12.0          17.0          22.0          14.0
# 149393           6.0          12.0          11.0          13.0          16.0
# 571             16.0          11.0          20.0          20.0          15.0
# 36154            4.0           4.0          12.0           6.0          11.0
# 156278          23.0          26.0          19.0          21.0          17.0
#
#         T1_wins_2003  T1_wins_2004  T1_wins_2005  T1_wins_2006  T1_wins_2007  \
# 15903           15.0          17.0          11.0          21.0          17.0
# 149393          21.0          14.0          17.0           9.0          23.0
# 571             17.0          13.0          18.0          24.0          27.0
# 36154           13.0          20.0          22.0          23.0          29.0
# 156278          14.0          17.0           8.0           8.0          12.0
#
#         T1_wins_2008  T1_wins_2009  T1_wins_2010  T1_wins_2011  T1_wins_2012  \
# 15903           10.0          13.0          12.0          13.0          13.0
# 149393          25.0          21.0           7.0           9.0          14.0
# 571             22.0          23.0          26.0          26.0          24.0
# 36154           32.0          29.0          26.0          31.0          26.0
# 156278          12.0          14.0          13.0          10.0           6.0
#
#         T1_wins_2013  T1_wins_2014  T1_wins_2015  T1_wins_2016  T1_wins_2017  \
# 15903           17.0          17.0          17.0          22.0          22.0
# 149393           7.0          15.0           8.0           4.0           7.0
# 571             22.0          29.0          29.0          27.0          24.0
# 36154           26.0          27.0          21.0          16.0          15.0
# 156278           9.0          13.0           9.0           4.0          15.0
#
#         T1_losses_1998  T1_losses_1999  T1_losses_2000  T1_losses_2001  \
# 15903             16.0            15.0            11.0            10.0
# 149393            19.0            16.0            17.0            14.0
# 571               11.0            20.0            10.0             9.0
# 36154             22.0            23.0            17.0            22.0
# 156278             9.0             6.0            12.0            10.0
#
#         T1_losses_2002  T1_losses_2003  T1_losses_2004  T1_losses_2005  \
# 15903             14.0            13.0            13.0            18.0
# 149393            11.0             7.0            17.0            14.0
# 571               11.0            12.0            18.0            11.0
# 36154             16.0            16.0            11.0             7.0
# 156278            12.0            15.0            10.0            20.0
#
#         T1_losses_2006  T1_losses_2007  T1_losses_2008  T1_losses_2009  \
# 15903             10.0            13.0            21.0            17.0
# 149393            20.0             9.0             8.0            12.0
# 571                6.0             6.0             9.0             9.0
# 36154              7.0             6.0             3.0             4.0
# 156278            21.0            18.0            19.0            17.0
#
#         T1_losses_2010  T1_losses_2011  T1_losses_2012  T1_losses_2013  \
# 15903             18.0            18.0            18.0            14.0
# 149393            23.0            22.0            17.0            23.0
# 571                7.0             8.0             7.0            10.0
# 36154              8.0             3.0             8.0             7.0
# 156278            18.0            20.0            22.0            21.0
#
#         T1_losses_2014  T1_losses_2015  T1_losses_2016  T1_losses_2017  \
# 15903             13.0            13.0            10.0            11.0
# 149393            17.0            19.0            22.0            22.0
# 571                6.0             4.0             6.0             8.0
# 36154              7.0            11.0            16.0            17.0
# 156278            19.0            21.0            26.0            16.0
#
#         T1_win_scores_1998  T1_win_scores_1999  T1_win_scores_2000  \
# 15903                731.0               887.0              1328.0
# 149393               447.0               843.0               780.0
# 571                 1122.0               751.0              1521.0
# 36154                268.0               258.0               761.0
# 156278              1785.0              1934.0              1257.0
#
#         T1_win_scores_2001  T1_win_scores_2002  T1_win_scores_2003  \
# 15903               1719.0              1062.0              1104.0
# 149393              1017.0              1205.0              1497.0
# 571                 1491.0              1067.0              1288.0
# 36154                494.0               839.0               862.0
# 156278              1559.0              1170.0               996.0
#
#         T1_win_scores_2004  T1_win_scores_2005  T1_win_scores_2006  \
# 15903               1317.0               755.0              1555.0
# 149393               975.0              1260.0               688.0
# 571                  896.0              1229.0              1681.0
# 36154               1316.0              1348.0              1524.0
# 156278              1254.0               559.0               641.0
#
#         T1_win_scores_2007  T1_win_scores_2008  T1_win_scores_2009  \
# 15903               1275.0               685.0               871.0
# 149393              1656.0              1921.0              1536.0
# 571                 2004.0              1655.0              1696.0
# 36154               2032.0              2364.0              2155.0
# 156278               916.0               865.0              1019.0
#
#         T1_win_scores_2010  T1_win_scores_2011  T1_win_scores_2012  \
# 15903                843.0               871.0               898.0
# 149393               451.0               565.0               833.0
# 571                 1909.0              1871.0              1563.0
# 36154               1836.0              2125.0              1783.0
# 156278               990.0               727.0               398.0
#
#         T1_win_scores_2013  T1_win_scores_2014  T1_win_scores_2015  \
# 15903               1335.0              1299.0              1153.0
# 149393               437.0               979.0               589.0
# 571                 1597.0              2190.0              2237.0
# 36154               1753.0              2019.0              1412.0
# 156278               586.0               892.0               654.0
#
#         T1_win_scores_2016  T1_win_scores_2017  T1_loss_scores_1998  \
# 15903               1630.0              1534.0                995.0
# 149393               311.0               486.0               1101.0
# 571                 1933.0              1760.0                647.0
# 36154               1115.0              1056.0               1237.0
# 156278               244.0               988.0                498.0
#
#         T1_loss_scores_1999  T1_loss_scores_2000  T1_loss_scores_2001  \
# 15903                 881.0                731.0                708.0
# 149393                980.0               1072.0                913.0
# 571                  1086.0                675.0                527.0
# 36154                1292.0                885.0               1290.0
# 156278                400.0                687.0                630.0
#
#         T1_loss_scores_2002  T1_loss_scores_2003  T1_loss_scores_2004  \
# 15903                 794.0                767.0                810.0
# 149393                639.0                416.0                991.0
# 571                   571.0                684.0               1079.0
# 36154                 992.0                876.0                583.0
# 156278                757.0                897.0                526.0
#
#         T1_loss_scores_2005  T1_loss_scores_2006  T1_loss_scores_2007  \
# 15903                 979.0                598.0                821.0
# 149393                882.0               1302.0                547.0
# 571                   634.0                373.0                387.0
# 36154                 369.0                400.0                327.0
# 156278               1177.0               1280.0               1156.0
#
#         T1_loss_scores_2008  T1_loss_scores_2009  T1_loss_scores_2010  \
# 15903                1125.0                947.0               1014.0
# 149393                528.0                719.0               1314.0
# 571                   552.0                531.0                428.0
# 36154                 138.0                243.0                456.0
# 156278               1054.0                977.0                977.0
#
#         T1_loss_scores_2011  T1_loss_scores_2012  T1_loss_scores_2013  \
# 15903                 971.0                996.0                707.0
# 149393               1134.0                796.0               1080.0
# 571                   524.0                385.0                554.0
# 36154                 156.0                428.0                356.0
# 156278               1069.0               1121.0               1045.0
#
#         T1_loss_scores_2014  T1_loss_scores_2015  T1_loss_scores_2016  \
# 15903                 809.0                748.0                545.0
# 149393                986.0               1015.0               1254.0
# 571                   432.0                268.0                357.0
# 36154                 441.0                625.0                878.0
# 156278                996.0               1114.0               1324.0
#
#         T1_loss_scores_2017  T2_wins_1998  T2_wins_1999  T2_wins_2000  \
# 15903                 655.0          24.0          23.0          20.0
# 149393               1118.0          18.0          17.0          10.0
# 571                   490.0          15.0          21.0          19.0
# 36154                 916.0           4.0          11.0          11.0
# 156278                843.0           4.0           8.0           7.0
#
#         T2_wins_2001  T2_wins_2002  T2_wins_2003  T2_wins_2004  T2_wins_2005  \
# 15903           12.0           3.0          11.0           9.0          12.0
# 149393           8.0          10.0          15.0          16.0          18.0
# 571             11.0          12.0          10.0           9.0           9.0
# 36154           15.0          14.0          10.0           9.0           3.0
# 156278          11.0          12.0          13.0          12.0          15.0
#
#         T2_wins_2006  T2_wins_2007  T2_wins_2008  T2_wins_2009  T2_wins_2010  \
# 15903           16.0          11.0          16.0          18.0          15.0
# 149393          15.0          22.0          19.0          12.0          13.0
# 571             12.0          12.0           8.0          14.0          10.0
# 36154            8.0          11.0          20.0          10.0           6.0
# 156278          12.0           9.0          15.0          19.0          18.0
#
#         T2_wins_2011  T2_wins_2012  T2_wins_2013  T2_wins_2014  T2_wins_2015  \
# 15903           20.0          21.0          19.0          13.0          15.0
# 149393          14.0          22.0          21.0          16.0           5.0
# 571              8.0          14.0          15.0          19.0           8.0
# 36154            4.0          10.0          12.0          14.0          15.0
# 156278          15.0          19.0          13.0          15.0          13.0
#
#         T2_wins_2016  T2_wins_2017  T2_losses_1998  T2_losses_1999  \
# 15903            6.0           8.0             8.0            10.0
# 149393          11.0           6.0             8.0             9.0
# 571              9.0          12.0            12.0             7.0
# 36154           14.0          16.0            18.0            15.0
# 156278          16.0          15.0            22.0            20.0
#
#         T2_losses_2000  T2_losses_2001  T2_losses_2002  T2_losses_2003  \
# 15903             10.0            17.0            25.0            18.0
# 149393            17.0            19.0            18.0            15.0
# 571                9.0            13.0            16.0            18.0
# 36154             14.0            12.0            12.0            17.0
# 156278            21.0            17.0            16.0            15.0
#
#         T2_losses_2004  T2_losses_2005  T2_losses_2006  T2_losses_2007  \
# 15903             19.0            15.0            12.0            20.0
# 149393            12.0            11.0            12.0             8.0
# 571               18.0            19.0            16.0            17.0
# 36154             18.0            24.0            19.0            15.0
# 156278            17.0            14.0            16.0            20.0
#
#         T2_losses_2008  T2_losses_2009  T2_losses_2010  T2_losses_2011  \
# 15903             15.0            13.0            15.0            12.0
# 149393            11.0            18.0            15.0            17.0
# 571               22.0            16.0            18.0            21.0
# 36154              9.0            16.0            20.0            22.0
# 156278            15.0            11.0            13.0            17.0
#
#         T2_losses_2012  T2_losses_2013  T2_losses_2014  T2_losses_2015  \
# 15903             13.0            14.0            19.0            17.0
# 149393             9.0            12.0            16.0            25.0
# 571               16.0            16.0            13.0            22.0
# 36154             16.0            15.0            14.0            13.0
# 156278            13.0            19.0            16.0            20.0
#
#         T2_losses_2016  T2_losses_2017  T2_win_scores_1998  \
# 15903             25.0            22.0              1646.0
# 149393            19.0            23.0              1453.0
# 571               21.0            18.0              1141.0
# 36154             14.0            11.0               281.0
# 156278            15.0            15.0               282.0
#
#         T2_win_scores_1999  T2_win_scores_2000  T2_win_scores_2001  \
# 15903               1526.0              1466.0               944.0
# 149393              1359.0               744.0               570.0
# 571                 1586.0              1427.0               776.0
# 36154                853.0               811.0              1047.0
# 156278               616.0               443.0               810.0
#
#         T2_win_scores_2002  T2_win_scores_2003  T2_win_scores_2004  \
# 15903                232.0               757.0               649.0
# 149393               754.0              1087.0              1076.0
# 571                  876.0               804.0               652.0
# 36154                939.0               692.0               627.0
# 156278               838.0               961.0               846.0
#
#         T2_win_scores_2005  T2_win_scores_2006  T2_win_scores_2007  \
# 15903                797.0              1175.0               755.0
# 149393              1232.0               989.0              1581.0
# 571                  596.0               851.0               825.0
# 36154                196.0               553.0               710.0
# 156278              1143.0               978.0               581.0
#
#         T2_win_scores_2008  T2_win_scores_2009  T2_win_scores_2010  \
# 15903               1102.0              1330.0              1145.0
# 149393              1306.0               887.0               958.0
# 571                  548.0               881.0               603.0
# 36154               1413.0               636.0               429.0
# 156278               947.0              1353.0              1191.0
#
#         T2_win_scores_2011  T2_win_scores_2012  T2_win_scores_2013  \
# 15903               1583.0              1572.0              1387.0
# 149393               966.0              1445.0              1407.0
# 571                  554.0               873.0               936.0
# 36154                245.0               586.0               792.0
# 156278              1173.0              1449.0               985.0
#
#         T2_win_scores_2014  T2_win_scores_2015  T2_win_scores_2016  \
# 15903                997.0              1014.0               419.0
# 149393              1221.0               331.0               721.0
# 571                 1445.0               542.0               541.0
# 36154                984.0               997.0               990.0
# 156278              1111.0               951.0              1031.0
#
#         T2_win_scores_2017  T2_loss_scores_1998  T2_loss_scores_1999  \
# 15903                578.0                475.0                566.0
# 149393               400.0                539.0                622.0
# 571                  778.0                692.0                479.0
# 36154               1065.0               1044.0                939.0
# 156278              1039.0               1216.0               1175.0
#
#         T2_loss_scores_2000  T2_loss_scores_2001  T2_loss_scores_2002  \
# 15903                 647.0               1041.0               1342.0
# 149393               1035.0               1126.0               1207.0
# 571                   531.0                889.0               1068.0
# 36154                 781.0                703.0                771.0
# 156278               1163.0                967.0                863.0
#
#         T2_loss_scores_2003  T2_loss_scores_2004  T2_loss_scores_2005  \
# 15903                 969.0               1078.0                769.0
# 149393                899.0                720.0                711.0
# 571                  1177.0               1158.0               1087.0
# 36154                 946.0               1048.0               1251.0
# 156278                877.0               1029.0                881.0
#
#         T2_loss_scores_2006  T2_loss_scores_2007  T2_loss_scores_2008  \
# 15903                 681.0               1120.0                765.0
# 149393                755.0                514.0                643.0
# 571                   993.0                966.0               1189.0
# 36154                1164.0                817.0                476.0
# 156278                940.0               1057.0                747.0
#
#         T2_loss_scores_2009  T2_loss_scores_2010  T2_loss_scores_2011  \
# 15903                 727.0                883.0                655.0
# 149393               1074.0                899.0                947.0
# 571                   859.0                919.0               1122.0
# 36154                 824.0               1060.0               1079.0
# 156278                619.0                709.0                954.0
#
#         T2_loss_scores_2012  T2_loss_scores_2013  T2_loss_scores_2014  \
# 15903                 762.0                893.0               1137.0
# 149393                517.0                646.0               1000.0
# 571                   876.0                879.0                813.0
# 36154                 845.0                734.0                784.0
# 156278                756.0               1179.0                992.0
#
#         T2_loss_scores_2015  T2_loss_scores_2016  T2_loss_scores_2017  \
# 15903                1011.0               1268.0               1281.0
# 149393               1360.0               1067.0               1264.0
# 571                  1173.0               1155.0                985.0
# 36154                 643.0                735.0                614.0
# 156278               1260.0                853.0                871.0
#
#         seed_diff  T1_region_seed_na  T2_region_seed_na  T1_wins_1998_na  \
# 15903         0.0              False               True            False
# 149393        0.0              False               True            False
# 571           0.0               True               True            False
# 36154         0.0              False               True            False
# 156278        0.0               True               True            False
#
#         T1_wins_1999_na  T1_wins_2000_na  T1_wins_2001_na  T1_wins_2002_na  \
# 15903             False            False            False            False
# 149393            False            False            False            False
# 571               False            False            False            False
# 36154             False            False            False            False
# 156278            False            False            False            False
#
#         T1_wins_2003_na  T1_wins_2004_na  T1_wins_2005_na  T1_wins_2006_na  \
# 15903             False            False            False            False
# 149393            False            False            False            False
# 571               False            False            False            False
# 36154             False            False            False            False
# 156278            False            False            False            False
#
#         T1_wins_2007_na  T1_wins_2008_na  T1_wins_2009_na  T1_wins_2010_na  \
# 15903             False            False            False            False
# 149393            False            False            False            False
# 571               False            False            False            False
# 36154             False            False            False            False
# 156278            False            False            False            False
#
#         T1_wins_2011_na  T1_wins_2012_na  T1_wins_2013_na  T1_wins_2014_na  \
# 15903             False            False            False            False
# 149393            False            False            False            False
# 571               False            False            False            False
# 36154             False            False            False            False
# 156278            False            False            False            False
#
#         T1_wins_2015_na  T1_wins_2016_na  T1_wins_2017_na  T1_losses_1998_na  \
# 15903             False            False            False              False
# 149393            False            False            False              False
# 571               False            False            False              False
# 36154             False            False            False              False
# 156278            False            False            False              False
#
#         T1_losses_1999_na  T1_losses_2000_na  T1_losses_2001_na  \
# 15903               False              False              False
# 149393              False              False              False
# 571                 False              False              False
# 36154               False              False              False
# 156278              False              False              False
#
#         T1_losses_2002_na  T1_losses_2003_na  T1_losses_2004_na  \
# 15903               False              False              False
# 149393              False              False              False
# 571                 False              False              False
# 36154               False              False              False
# 156278              False              False              False
#
#         T1_losses_2005_na  T1_losses_2006_na  T1_losses_2007_na  \
# 15903               False              False              False
# 149393              False              False              False
# 571                 False              False              False
# 36154               False              False              False
# 156278              False              False              False
#
#         T1_losses_2008_na  T1_losses_2009_na  T1_losses_2010_na  \
# 15903               False              False              False
# 149393              False              False              False
# 571                 False              False              False
# 36154               False              False              False
# 156278              False              False              False
#
#         T1_losses_2011_na  T1_losses_2012_na  T1_losses_2013_na  \
# 15903               False              False              False
# 149393              False              False              False
# 571                 False              False              False
# 36154               False              False              False
# 156278              False              False              False
#
#         T1_losses_2014_na  T1_losses_2015_na  T1_losses_2016_na  \
# 15903               False              False              False
# 149393              False              False              False
# 571                 False              False              False
# 36154               False              False              False
# 156278              False              False              False
#
#         T1_losses_2017_na  T1_win_scores_1998_na  T1_win_scores_1999_na  \
# 15903               False                  False                  False
# 149393              False                  False                  False
# 571                 False                  False                  False
# 36154               False                  False                  False
# 156278              False                  False                  False
#
#         T1_win_scores_2000_na  T1_win_scores_2001_na  T1_win_scores_2002_na  \
# 15903                   False                  False                  False
# 149393                  False                  False                  False
# 571                     False                  False                  False
# 36154                   False                  False                  False
# 156278                  False                  False                  False
#
#         T1_win_scores_2003_na  T1_win_scores_2004_na  T1_win_scores_2005_na  \
# 15903                   False                  False                  False
# 149393                  False                  False                  False
# 571                     False                  False                  False
# 36154                   False                  False                  False
# 156278                  False                  False                  False
#
#         T1_win_scores_2006_na  T1_win_scores_2007_na  T1_win_scores_2008_na  \
# 15903                   False                  False                  False
# 149393                  False                  False                  False
# 571                     False                  False                  False
# 36154                   False                  False                  False
# 156278                  False                  False                  False
#
#         T1_win_scores_2009_na  T1_win_scores_2010_na  T1_win_scores_2011_na  \
# 15903                   False                  False                  False
# 149393                  False                  False                  False
# 571                     False                  False                  False
# 36154                   False                  False                  False
# 156278                  False                  False                  False
#
#         T1_win_scores_2012_na  T1_win_scores_2013_na  T1_win_scores_2014_na  \
# 15903                   False                  False                  False
# 149393                  False                  False                  False
# 571                     False                  False                  False
# 36154                   False                  False                  False
# 156278                  False                  False                  False
#
#         T1_win_scores_2015_na  T1_win_scores_2016_na  T1_win_scores_2017_na  \
# 15903                   False                  False                  False
# 149393                  False                  False                  False
# 571                     False                  False                  False
# 36154                   False                  False                  False
# 156278                  False                  False                  False
#
#         T1_loss_scores_1998_na  T1_loss_scores_1999_na  \
# 15903                    False                   False
# 149393                   False                   False
# 571                      False                   False
# 36154                    False                   False
# 156278                   False                   False
#
#         T1_loss_scores_2000_na  T1_loss_scores_2001_na  \
# 15903                    False                   False
# 149393                   False                   False
# 571                      False                   False
# 36154                    False                   False
# 156278                   False                   False
#
#         T1_loss_scores_2002_na  T1_loss_scores_2003_na  \
# 15903                    False                   False
# 149393                   False                   False
# 571                      False                   False
# 36154                    False                   False
# 156278                   False                   False
#
#         T1_loss_scores_2004_na  T1_loss_scores_2005_na  \
# 15903                    False                   False
# 149393                   False                   False
# 571                      False                   False
# 36154                    False                   False
# 156278                   False                   False
#
#         T1_loss_scores_2006_na  T1_loss_scores_2007_na  \
# 15903                    False                   False
# 149393                   False                   False
# 571                      False                   False
# 36154                    False                   False
# 156278                   False                   False
#
#         T1_loss_scores_2008_na  T1_loss_scores_2009_na  \
# 15903                    False                   False
# 149393                   False                   False
# 571                      False                   False
# 36154                    False                   False
# 156278                   False                   False
#
#         T1_loss_scores_2010_na  T1_loss_scores_2011_na  \
# 15903                    False                   False
# 149393                   False                   False
# 571                      False                   False
# 36154                    False                   False
# 156278                   False                   False
#
#         T1_loss_scores_2012_na  T1_loss_scores_2013_na  \
# 15903                    False                   False
# 149393                   False                   False
# 571                      False                   False
# 36154                    False                   False
# 156278                   False                   False
#
#         T1_loss_scores_2014_na  T1_loss_scores_2015_na  \
# 15903                    False                   False
# 149393                   False                   False
# 571                      False                   False
# 36154                    False                   False
# 156278                   False                   False
#
#         T1_loss_scores_2016_na  T1_loss_scores_2017_na  T2_wins_1998_na  \
# 15903                    False                   False            False
# 149393                   False                   False            False
# 571                      False                   False            False
# 36154                    False                   False            False
# 156278                   False                   False            False
#
#         T2_wins_1999_na  T2_wins_2000_na  T2_wins_2001_na  T2_wins_2002_na  \
# 15903             False            False            False            False
# 149393            False            False            False            False
# 571               False            False            False            False
# 36154             False            False            False            False
# 156278            False            False            False            False
#
#         T2_wins_2003_na  T2_wins_2004_na  T2_wins_2005_na  T2_wins_2006_na  \
# 15903             False            False            False            False
# 149393            False            False            False            False
# 571               False            False            False            False
# 36154             False            False            False            False
# 156278            False            False            False            False
#
#         T2_wins_2007_na  T2_wins_2008_na  T2_wins_2009_na  T2_wins_2010_na  \
# 15903             False            False            False            False
# 149393            False            False            False            False
# 571               False            False            False            False
# 36154             False            False            False            False
# 156278            False            False            False            False
#
#         T2_wins_2011_na  T2_wins_2012_na  T2_wins_2013_na  T2_wins_2014_na  \
# 15903             False            False            False            False
# 149393            False            False            False            False
# 571               False            False            False            False
# 36154             False            False            False            False
# 156278            False            False            False            False
#
#         T2_wins_2015_na  T2_wins_2016_na  T2_wins_2017_na  T2_losses_1998_na  \
# 15903             False            False            False              False
# 149393            False            False            False              False
# 571               False            False            False              False
# 36154             False            False            False              False
# 156278            False            False            False              False
#
#         T2_losses_1999_na  T2_losses_2000_na  T2_losses_2001_na  \
# 15903               False              False              False
# 149393              False              False              False
# 571                 False              False              False
# 36154               False              False              False
# 156278              False              False              False
#
#         T2_losses_2002_na  T2_losses_2003_na  T2_losses_2004_na  \
# 15903               False              False              False
# 149393              False              False              False
# 571                 False              False              False
# 36154               False              False              False
# 156278              False              False              False
#
#         T2_losses_2005_na  T2_losses_2006_na  T2_losses_2007_na  \
# 15903               False              False              False
# 149393              False              False              False
# 571                 False              False              False
# 36154               False              False              False
# 156278              False              False              False
#
#         T2_losses_2008_na  T2_losses_2009_na  T2_losses_2010_na  \
# 15903               False              False              False
# 149393              False              False              False
# 571                 False              False              False
# 36154               False              False              False
# 156278              False              False              False
#
#         T2_losses_2011_na  T2_losses_2012_na  T2_losses_2013_na  \
# 15903               False              False              False
# 149393              False              False              False
# 571                 False              False              False
# 36154               False              False              False
# 156278              False              False              False
#
#         T2_losses_2014_na  T2_losses_2015_na  T2_losses_2016_na  \
# 15903               False              False              False
# 149393              False              False              False
# 571                 False              False              False
# 36154               False              False              False
# 156278              False              False              False
#
#         T2_losses_2017_na  T2_win_scores_1998_na  T2_win_scores_1999_na  \
# 15903               False                  False                  False
# 149393              False                  False                  False
# 571                 False                  False                  False
# 36154               False                  False                  False
# 156278              False                  False                  False
#
#         T2_win_scores_2000_na  T2_win_scores_2001_na  T2_win_scores_2002_na  \
# 15903                   False                  False                  False
# 149393                  False                  False                  False
# 571                     False                  False                  False
# 36154                   False                  False                  False
# 156278                  False                  False                  False
#
#         T2_win_scores_2003_na  T2_win_scores_2004_na  T2_win_scores_2005_na  \
# 15903                   False                  False                  False
# 149393                  False                  False                  False
# 571                     False                  False                  False
# 36154                   False                  False                  False
# 156278                  False                  False                  False
#
#         T2_win_scores_2006_na  T2_win_scores_2007_na  T2_win_scores_2008_na  \
# 15903                   False                  False                  False
# 149393                  False                  False                  False
# 571                     False                  False                  False
# 36154                   False                  False                  False
# 156278                  False                  False                  False
#
#         T2_win_scores_2009_na  T2_win_scores_2010_na  T2_win_scores_2011_na  \
# 15903                   False                  False                  False
# 149393                  False                  False                  False
# 571                     False                  False                  False
# 36154                   False                  False                  False
# 156278                  False                  False                  False
#
#         T2_win_scores_2012_na  T2_win_scores_2013_na  T2_win_scores_2014_na  \
# 15903                   False                  False                  False
# 149393                  False                  False                  False
# 571                     False                  False                  False
# 36154                   False                  False                  False
# 156278                  False                  False                  False
#
#         T2_win_scores_2015_na  T2_win_scores_2016_na  T2_win_scores_2017_na  \
# 15903                   False                  False                  False
# 149393                  False                  False                  False
# 571                     False                  False                  False
# 36154                   False                  False                  False
# 156278                  False                  False                  False
#
#         T2_loss_scores_1998_na  T2_loss_scores_1999_na  \
# 15903                    False                   False
# 149393                   False                   False
# 571                      False                   False
# 36154                    False                   False
# 156278                   False                   False
#
#         T2_loss_scores_2000_na  T2_loss_scores_2001_na  \
# 15903                    False                   False
# 149393                   False                   False
# 571                      False                   False
# 36154                    False                   False
# 156278                   False                   False
#
#         T2_loss_scores_2002_na  T2_loss_scores_2003_na  \
# 15903                    False                   False
# 149393                   False                   False
# 571                      False                   False
# 36154                    False                   False
# 156278                   False                   False
#
#         T2_loss_scores_2004_na  T2_loss_scores_2005_na  \
# 15903                    False                   False
# 149393                   False                   False
# 571                      False                   False
# 36154                    False                   False
# 156278                   False                   False
#
#         T2_loss_scores_2006_na  T2_loss_scores_2007_na  \
# 15903                    False                   False
# 149393                   False                   False
# 571                      False                   False
# 36154                    False                   False
# 156278                   False                   False
#
#         T2_loss_scores_2008_na  T2_loss_scores_2009_na  \
# 15903                    False                   False
# 149393                   False                   False
# 571                      False                   False
# 36154                    False                   False
# 156278                   False                   False
#
#         T2_loss_scores_2010_na  T2_loss_scores_2011_na  \
# 15903                    False                   False
# 149393                   False                   False
# 571                      False                   False
# 36154                    False                   False
# 156278                   False                   False
#
#         T2_loss_scores_2012_na  T2_loss_scores_2013_na  \
# 15903                    False                   False
# 149393                   False                   False
# 571                      False                   False
# 36154                    False                   False
# 156278                   False                   False
#
#         T2_loss_scores_2014_na  T2_loss_scores_2015_na  \
# 15903                    False                   False
# 149393                   False                   False
# 571                      False                   False
# 36154                    False                   False
# 156278                   False                   False
#
#         T2_loss_scores_2016_na  T2_loss_scores_2017_na  seed_diff_na
# 15903                    False                   False          True
# 149393                   False                   False          True
# 571                      False                   False          True
# 36154                    False                   False          True
# 156278                   False                   False          True

# %%
def get_pred(x):
    y_ = m.predict(x)
    return y_.clip(1e-9,1-1e-9)

def crit(y, y_):
    crit = ( y*np.log(y_) ) + ( (1 - y)*np.log(1 - y_) )
    return -crit.mean()

def rf_score():
    yh_train = get_pred(x_train)
    print(f'Train score     : crit={crit(y_train, yh_train):0.4f}, r2={r2_score(y_train, yh_train):0.4f}')
    if x_val.shape[0] > 0:
        yh_val = get_pred(x_val)
        print(f'Validation score: crit={crit(y_val, yh_val):0.4f}, r2={r2_score(y_val, yh_val):0.4f}')
    if m.oob_score:
        print(f'Oob score       : {" "*13}r2={m.oob_score_:0.4f}')

# %%
x_train.shape
# Out:
# (156712, 334)

# %%
n_cpu = cpu_count()
n_cpu
# Out:
# 12

# %%
m = RandomForestRegressor(100, min_samples_split=25, min_samples_leaf=10, max_features=150,
                          oob_score=True, n_jobs=n_cpu)
m.fit(x_train, y_train)
rf_score()
# Out:
# Train score     : crit=0.4175, r2=0.4649
# Validation score: crit=0.5404, r2=0.2706
# Oob score       :              r2=0.2664

# %% [markdown]
# Public leaderboard: 0.303330 (on full train data and 1000 estimators)
#
# TODO:
# * Only use past seasons to train the model.

# %% [markdown]
# # Exploring

# %%
pd.DataFrame({'col': x_train.columns, 'imp': m.feature_importances_}).sort_values('imp').plot(
    'col', 'imp', 'barh', figsize=(12,80));

# %%
x_val.reset_index(drop=True, inplace=True)
y_ = get_pred(x_val)

# %%
res = x_val.copy()
res['crit'] = np.abs(y_val - y_)
res.sort_values('crit', ascending=False, inplace=True)

# %%
for col in x_train.columns:
    res.groupby(col)[['crit']].mean().reset_index().plot.bar(col, 'crit', legend=False, figsize=(15,5))

# %% [markdown]
# # Submission file

# %% [markdown]
# ID - this is a 14-character string of the format SSSS_XXXX_YYYY, where SSSS is the four digit season number, XXXX is the four-digit TeamID of the lower-ID team, and YYYY is the four-digit TeamID of the higher-ID team.
# Pred - this contains the predicted winning percentage for the first team identified in the ID field

# %%
df_submission = pd.read_csv(path / 'WSampleSubmissionStage1.csv')

# %%
df_submission['Season'] = df_submission.ID.str.slice(stop=4).astype(int)
df_submission['T1'] = df_submission.ID.str.slice(5, 9).astype(int)
df_submission['T2'] = df_submission.ID.str.slice(10).astype(int)
df_submission = add_seed_data(df_submission)
df_submission = add_results_data(df_submission)
df_submission['seed_diff'] = df_submission.T1_region_seed - df_submission.T2_region_seed
df_submission.drop('ID', axis=1, inplace=True)
df_submission['NCAA'] = True
apply_cats(df_submission, df_data)

# %%
df_submission.to_feather('data/df_submission')

# %%
# !ls -lh data
# Out:
# total 265M
# -rw-r--r-- 1 rhermoza rhermoza 255M Feb 26 00:23 df_data
# -rw-r--r-- 1 rhermoza rhermoza  11M Feb 26 00:35 df_submission

# %%
x_sub, _, _ = proc_df(df_submission, 'Pred', na_dict=nas)
y_sub = get_pred(x_sub)
x_sub['Pred'] = y_sub
x_sub['ID'] = x_sub.apply(lambda x: f'{x.Season}_{x.T1}_{x.T2}', axis=1)

x_sub[['ID', 'Pred']].to_csv('result.csv', index=False)

# %%
pd.read_csv('result.csv').head()
# Out:
#                ID      Pred
# 0  2014_3103_3107  0.600615
# 1  2014_3103_3113  0.199274
# 2  2014_3103_3119  0.450918
# 3  2014_3103_3124  0.018030
# 4  2014_3103_3140  0.332969

# %%
from IPython.display import FileLink
FileLink('result.csv')
# Out:
# /home/rhermoza/github/kaggle/kaggle-basket/woman/result.csv

# %% [markdown]
# # ---
